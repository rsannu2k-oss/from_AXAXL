# %%
# %sql
create or replace table xliidw_dev_lpl.staging_genius.XrefCovrgMappingAnalysis
deep clone xliidw_dev_lpl.staging_nxref.XrefCovrgMappingAnalysis
location 'abfss://z-xlc-0266-xlii-dv-ue2-dlc05-xliidw@zxlc0149adlsdvue2dls01.dfs.core.windows.net/xliidw_dev_lpl/test/staging_geniu_restore/XrefCovrgMappingAnalysis'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_table_size</th><th>source_num_of_files</th><th>num_of_synced_transactions</th><th>num_removed_files</th><th>num_copied_files</th><th>removed_files_size</th><th>copied_files_size</th></tr></thead><tbody><tr><td>4187</td><td>1</td><td>null</td><td>0</td><td>1</td><td>0</td><td>4187</td></tr></tbody></table></div>

# %%
# %sql
select ai_query(request => "write a query to fetch all the storage container information for staging_wins database", endpoint => "https://westus2.api.cognitive.microsoft.com/", key => "");
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5447102850094615>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select ai_query(request => "write a query to fetch all the storage container information for staging_wins database", endpoint => "https://westus2.api.cognitive.microsoft.com/", key => "");\n')
#
# File /databricks/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
-- select ai_extract("John went to the city of New York and visited the Statue of Liberty.", array("city"))
select ai_extract("John went to New York and visited the Statue of Liberty.", array("city"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ai_extract(John went to New York and visited the Statue of Liberty., array(city))</th></tr></thead><tbody><tr><td>List(New York)</td></tr></tbody></table></div>

# %%
import os
import re
 
# List of tables you want to check
tables = ['LK_CoverageBandings']  
# Replace with your actual table names
 
# Directory containing the .dtsx files
dtsx_directory = '/Volumes/xliidw_dev_lpl/application/adhoc_files/EDS_Files/'
 
#files = dbutils.fs.ls(dtsx_directory)
#count=sum(1 for file in files if file.path.endswith(".dtsx"))
#print (f"Found {count} files in {dtsx_directory}")
 
trim_tables =[t.strip() for t in tables]
 
# Compile regex patterns for efficiency
table_patterns = [re.compile(r'\b' + re.escape(table) + r'\b', re.IGNORECASE) for table in trim_tables]
 
# Function to check if line contains SELECT and references any table
def check_line_for_tables(line):
    # Basic check if line contains SELECT
    if 'select' in line.lower():
        for pattern in table_patterns:
            if pattern.search(line):
                return True
    return False
 
# Iterate through all files in the directory
for filename in os.listdir(dtsx_directory):
    if filename.endswith('.dtsx'):
        file_path = os.path.join(dtsx_directory, filename)
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
            for line_number, line in enumerate(file, 1):
                if check_line_for_tables(line):
                    print(f"Found reference in {filename} (Line {line_number}): {line.strip()}")
# Out:
# Found reference in EDS_d_CoverageBandings.dtsx (Line 132): SQLTask:SqlStatementSource="INSERT INTO LK_CoverageBandings&#xA;(FKCcy, SequenceNo, LowerBand, UpperBand)&#xA;SELECT &#xA;&#x9;FKCcy, &#xA;&#x9;SequenceNo,&#xA;&#x9;LowerBand,&#xA;&#x9;UpperBand&#xA;FROM CoverageBandings&#xA;GO&#xA;&#xA;ALTER TABLE [dbo].[LK_CoverageBandings] ADD CONSTRAINT [PK_LK_CoverageBandings] PRIMARY KEY  NONCLUSTERED &#xA;&#x9;(&#xA;&#x9;&#x9;[FKCcy],&#xA;&#x9;&#x9;[SequenceNo]&#xA;&#x9;)  ON [PRIMARY] &#xA;GO&#xA;" xmlns:SQLTask="www.microsoft.com/sqlserver/dts/tasks/sqltask" />
# ...
